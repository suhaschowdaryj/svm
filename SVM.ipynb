# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.cross_validation import train_test_split
from sklearn import svm
import numpy as np

#generating gaussian data
X1 = np.random.multivariate_normal([-1.5, -1.5], [[2, 0],[0, 2]], 3000)
X2 = np.random.multivariate_normal([1, 1], [[2, 0],[0, 2]], 3000)
y1=np.full(len(X1), -1, dtype=int)
y2=np.full(len(X2), 1, dtype=int)


#plot for raw data
plt.title('Raw data')
plt.scatter(X1[:, 0], X1[:, 1], c='g', marker='*', label='Class -1')
plt.scatter(X2[:, 0], X2[:, 1], c='m', marker='*', label='Class +1')
plt.xlim(-7, 7)
plt.ylim(-7, 7)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()


X = np.concatenate((X1, X2), axis=0)
y= np.concatenate((y1, y2), axis=0)

train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state=35)


#Plot for training data
plt.title('training data')
plt.scatter(train_x[train_y == -1, 0], train_x[train_y == -1, 1], c='g', marker='*', label='Class -1')
plt.scatter(train_x[train_y == 1, 0], train_x[train_y == 1, 1], c='m', marker='*', label='Class +1')
plt.xlim(-7, 7)
plt.ylim(-7, 7)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()


#plot for test data
plt.title('test data')
plt.scatter(test_x[test_y == -1, 0], test_x[test_y == -1, 1], c='g', marker='*', label='Class -1')
plt.scatter(test_x[test_y == 1, 0], test_x[test_y == 1, 1], c='m', marker='*', label='Class +1')
plt.xlim(-7, 7)
plt.ylim(-7, 7)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()


#fit linear kernel
linearsvm = svm.SVC(kernel='linear').fit(train_x, train_y)

#fit rbf kernel
rbfsvm = svm.SVC(kernel='rbf', gamma=10 ).fit(train_x, train_y)

#predict rbf svm
predict2 = rbf_svc.predict(test_x)
accuracy_rbfsvm = accuracy_score(test_y, predict2)

#predict linear svm
predict1 = linearsvm.predict(test_x)
accuracy_linearsvm = accuracy_score(test_y, predict1)


plt.title('linear svm classifier')
plt.scatter(test_x[predict1 == -1, 0], test_x[predict1 == -1, 1],c='g', marker='*', label='Class -1')
plt.scatter(test_x[predict1 == 1, 0], test_x[predict1 == 1, 1],c='m', marker='*', label='Class +1')
plt.xlim(-7, 7)
plt.ylim(-7, 7)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()




plt.title('rbf svm classifier')
plt.scatter(test_x[predict2 == -1, 0], test_x[predict2 == -1, 1],c='g', marker='*', label='Class -1')
plt.scatter(test_x[predict2 == 1, 0], test_x[predict2 == 1, 1],c='m', marker='*', label='Class +1')
plt.xlim(-7, 7)
plt.ylim(-7, 7)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

print("Linear svm accuracy rate-", accuracy_linearsvm*100)
print("rbf svm accuracy rate-", accuracy_rbfsvm*100)
# Out:
# Linear svm accuracy rate- 89.1666666667
# rbf svm accuracy rate- 88.6111111111
